# %%
# Install required packages
# !pip install transformers datasets torch pandas scikit-learn

import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
from sklearn.model_selection import train_test_split
import pickle
import logging

# Setup logging
logging.basicConfig(filename='finetune.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define clause_names (from your provided list)
clause_names = [
    'Affiliate License-Licensee', 'Affiliate License-Licensor', 'Agreement Date', 'Anti-Assignment',
    'Audit Rights', 'Cap On Liability', 'Change Of Control', 'Competitive Restriction Exception',
    'Covenant Not To Sue', 'Document Name', 'Effective Date', 'Exclusivity', 'Expiration Date',
    'Governing Law', 'Insurance', 'Ip Ownership Assignment', 'Irrevocable Or Perpetual License',
    'Joint Ip Ownership', 'License Grant', 'Liquidated Damages', 'Minimum Commitment',
    'Most Favored Nation', 'No-Solicit Of Customers', 'No-Solicit Of Employees', 'Non-Compete',
    'Non-Disparagement', 'Non-Transferable License', 'Notice Period To Terminate Renewal',
    'Parties', 'Post-Termination Services', 'Price Restrictions', 'Renewal Term',
    'Revenue/Profit Sharing', 'Rofr/Rofo/Rofn', 'Source Code Escrow', 'Termination For Convenience',
    'Third Party Beneficiary', 'Uncapped Liability', 'Unlimited/All-You-Can-Eat-License',
    'Volume Restriction', 'Warranty Duration', 'Uncategorized'
]

# Load dataset
DATASET_PATH = './clause_dataset.csv'
try:
    df = pd.read_csv(DATASET_PATH)
    df['labels'] = df['labels'].apply(lambda x: [float(i) for i in eval(x)])  # Convert to float32 list
    dataset = Dataset.from_pandas(df)
except FileNotFoundError:
    logging.error(f"Dataset file {DATASET_PATH} not found.")
    raise

# Split into train and validation (80-20 split)
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('nlpaueb/legal-bert-base-uncased')
model = AutoModelForSequenceClassification.from_pretrained(
    'nlpaueb/legal-bert-base-uncased',
    num_labels=len(clause_names),
    problem_type='multi_label_classification'
)

# Move model to CPU explicitly (remove this if GPU is available)
device = torch.device('cpu')
model.to(device)

# Tokenize dataset
def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)

train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])
val_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])

# Define metrics
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = (torch.sigmoid(torch.tensor(logits)) > 0.5).int()
    accuracy = (predictions == labels).float().mean().item()
    return {'accuracy': accuracy}

# Set training arguments
training_args = TrainingArguments(
    output_dir='./legalbert-finetuned',
    num_train_epochs=5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    learning_rate=2e-5,
    eval_strategy='epoch',  # Updated from evaluation_strategy
    save_strategy='epoch',
    load_best_model_at_end=True,
    metric_for_best_model='accuracy',
    logging_dir='./logs',
    logging_steps=10,
    weight_decay=0.01,
    no_cuda=True,  # Explicitly disable CUDA for CPU-only
    dataloader_pin_memory=False,  # Disable pin_memory for CPU
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
)

# Train model with error handling
try:
    trainer.train()
except Exception as e:
    logging.error(f"Training failed: {str(e)}")
    raise

# Save model and tokenizer to .pkl
MODEL_PKL_PATH = './legalbert_finetuned.pkl'
with open(MODEL_PKL_PATH, 'wb') as f:
    pickle.dump({'model': model, 'tokenizer': tokenizer}, f)
logging.info(f"Fine-tuned LegalBERT and tokenizer saved to {MODEL_PKL_PATH}")
# Out:
# Requirement already satisfied: transformers in c:\users\vani1\anaconda3\lib\site-packages (4.54.1)
# Requirement already satisfied: datasets in c:\users\vani1\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: torch in c:\users\vani1\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: pandas in c:\users\vani1\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\vani1\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: filelock in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vani1\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\vani1\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\vani1\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\vani1\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\vani1\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\vani1\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: six>=1.5 in c:\users\vani1\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vani1\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vani1\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vani1\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vani1\anaconda3\lib\site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\vani1\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vani1\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at nlpaueb/legal-bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/101 [00:00<?, ? examples/s]
# Map:   0%|          | 0/26 [00:00<?, ? examples/s]
# c:\Users\vani1\anaconda3\Lib\site-packages\transformers\training_args.py:1609: FutureWarning: using `no_cuda` is deprecated and will be removed in version 5.0 of 🤗 Transformers. Use `use_cpu` instead
#   warnings.warn(
# c:\Users\vani1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
#     <div>
#
#       <progress value='130' max='130' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [130/130 05:53, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.612800</td>
#       <td>0.513442</td>
#       <td>0.967949</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.439300</td>
#       <td>0.384303</td>
#       <td>0.973443</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.373600</td>
#       <td>0.319057</td>
#       <td>0.973443</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.320700</td>
#       <td>0.289853</td>
#       <td>0.973443</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.307500</td>
#       <td>0.282421</td>
#       <td>0.973443</td>
#     </tr>
#   </tbody>
# </table><p>
# c:\Users\vani1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# c:\Users\vani1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# c:\Users\vani1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# c:\Users\vani1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# !pip install datasets transformers scikit-learn spacy pandas
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: datasets in c:\users\vani1\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: transformers in c:\users\vani1\anaconda3\lib\site-packages (4.54.1)
# Requirement already satisfied: scikit-learn in c:\users\vani1\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: spacy in c:\users\vani1\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: pandas in c:\users\vani1\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: filelock in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (0.34.3)
# Requirement already satisfied: packaging in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\vani1\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\vani1\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\vani1\anaconda3\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vani1\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\vani1\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\vani1\anaconda3\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.11.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\vani1\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\vani1\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\vani1\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\vani1\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vani1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vani1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vani1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vani1\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\vani1\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\vani1\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\vani1\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\vani1\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\vani1\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\vani1\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vani1\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\vani1\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\vani1\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------- ------------------------------ 2.9/12.8 MB 15.3 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 14.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------- ------- 10.5/12.8 MB 14.5 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 12.0 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
